# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv('data/desafio1.csv')

# %%
dados
# Out:
#       RowNumber                                        id  \
# 0             1  e7f44fcbd380d4cef7e6c232cc7e37895c3fd197
# 1             2  28dcb083ad90512da16b9430085c2cddb8ca5e12
# 2             3  774bc378f787438c9c7594e536787d07a097a54b
# 3             4  043a71326f7096de155e7f0c559dc62b5e4b7239
# 4             5  37b3bb8ca243955fb3605ec7e1c2a4607cdb3b22
# 5             6  db5cf32c3fbc7c5d8f8313afca1d099de6dc055f
# 6             7  8f3cc64a0a84bab38fefb030f09757d0cbf03bb2
# 7             8  6704b822c203e2dda9f225dfc4f1bed2ae9044e6
# 8             9  35f41954a87f722a3960e5fa8ce898a09398a564
# 9            10  f110be36fc6171a7da472b9cbac8698df880aac6
# 10           11  616ab70b0c6c9bbca2053d3841890a9831c5e547
# 11           12  727d2911ca645148ecb222005c5f4f8ccf72b4d6
# 12           13  09470d0412441f628088863770edd8203a6d061a
# 13           14  572eae7cd6575a5b53f64a86086b145e7166c627
# 14           15  4f883154a84d3fda402e17686bfe212558f7f15e
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 12 columns):
# RowNumber                   7000 non-null int64
# id                          7000 non-null object
# sobrenome                   7000 non-null object
# pontuacao_credito           7000 non-null int64
# estado_residencia           7000 non-null object
# genero                      7000 non-null object
# idade                       7000 non-null int64
# nivel_estabilidade          7000 non-null int64
# saldo_conta                 7000 non-null float64
# numero_produtos             7000 non-null int64
# possui_cartao_de_credito    7000 non-null int64
# membro_ativo                7000 non-null int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 656.3+ KB

# %%
type(dados['pontuacao_credito'].mean())
# Out:
# float

# %%
estados = dados['estado_residencia'].unique()
submissao = pd.read_json('data/submission.json')
for i in estados:
    estado = dados[(dados['estado_residencia'] == i) ]['pontuacao_credito']
    submissao[i]['moda'] = estado.mode()
    submissao[i]['mediana'] = estado.median()
    submissao[i]['media'] = estado.mean()
    float(submissao[i]['media'])
    #submissao[i]['media'] = 3.287326
    print(submissao[i]['media'])
    submissao[i]['desvio_padrao'] = estado.std()
#submissao2 = submissao.astype(np.float64)
#print(type(submissao2['SC']['desvio_padrao']))
submissao.head()
# Out:
# 649
# 651
# 648
#                 SC   RS   PR
# desvio_padrao   97   95   98
# media          649  651  648
# mediana        653  650  650
# moda           850  850  850

# %%
estados = dados['estado_residencia'].unique()
submissao = pd.DataFrame()
    
for i in estados:
    estado = dados[(dados['estado_residencia'] == i) ]['pontuacao_credito']
    submissao[i] = []
    submissao[i]['moda'] = estado.mode()
    submissao[i]['mediana'] = estado.median()
    submissao[i]['media'] = estado.mean()
    print(submissao[i]['media'])
    submissao[i]['desvio_padrao'] = estado.std()
#submissao2 = submissao.astype(np.float64)
#print(type(submissao2['SC']['desvio_padrao']))
submissao
# Out:
# 649.5376527422563
# 651.1051428571428
# 648.9612940496822
# Empty DataFrame
# Columns: [SC, RS, PR]
# Index: []

# %%
def resposta(dataframe):
    estados = dataframe['estado_residencia'].unique()
    submissao = pd.DataFrame()
    for i in estados:
        estado = dados[(dados['estado_residencia'] == i) ]['pontuacao_credito']
        submissao[i] = []
        submissao[i]['moda'] = estado.mode()
        submissao[i]['mediana'] = estado.median()
        submissao[i]['media'] = estado.mean()
        print(submissao[i]['media'])
        submissao[i]['desvio_padrao'] = estado.std()
    #submissao2 = submissao.astype(np.float64)
    #print(type(submissao2['SC']['desvio_padrao']))
    submissao.to_json('submission.json', double_precision=15)
    return submissao

# %%
resposta(dados)
# Out:
# 649.5376527422563
# 651.1051428571428
# 648.9612940496822
# Empty DataFrame
# Columns: [SC, RS, PR]
# Index: []

# %%
submissao = pd.read_json('submission.json')
submissao
# Out:
#                 SC   RS   PR
# desvio_padrao   97   95   98
# media          649  651  648
# mediana        653  650  650
# moda           850  850  850
